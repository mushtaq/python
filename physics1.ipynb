# %%
import pandas as pd

# %%
df = pd.DataFrame({'u': [0, 2, 2, 2, 2, 3, 3]})

# %%
df['a'] = df.u.diff().shift(-1).fillna(method= 'ffill')

# %%
df['ds'] = df.u + df.a/2

# %%
df['s'] = df.ds.cumsum()

# %%
del df['ds']
df.plot()
