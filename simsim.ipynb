# %%
import sympy
from sympy import *
from sympy.plotting import plot

# %%
s, u, v, a, t, d = symbols('s u v a t d')

# %%
s = u*t + Rational(1/2) * a * t ** 2
s
# Out:
# a*t**2/2 + t*u

# %%
v = diff(s, t)
v
# Out:
# a*t + u

# %%
a = diff(v, t)
a
# Out:
# a

# %%
a = Piecewise((3, t <= 6), (0, (d <= 16).subs(d, 6 < t)), (-4.5, t > 16))

# %%
a
# Out:
# Piecewise((3, t <= 6), (0, (t > 6) <= 16), (-4.5, t > 16))

# %%
plot(a)
